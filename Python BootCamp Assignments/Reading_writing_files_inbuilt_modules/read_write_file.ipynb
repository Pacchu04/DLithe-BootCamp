# %% [markdown]
# ### Pandas: Pandas is a powerful and flexible open-source data analysis and manipulation library for Python. It provides data structures like Series (one-dimensional) and DataFrame (two-dimensional), which are designed to handle and manipulate large datasets efficiently

# %% [markdown]
# ### Reading and Writing CSV Files with Pandas

# %%
import pandas as pd

df = pd.read_csv('industry.csv')

#Adding another column
df["New_Column"] = ''

df.head()
# Out:
#                         Industry New_Column
# 0             Accounting/Finance
# 1   Advertising/Public Relations
# 2             Aerospace/Aviation
# 3  Arts/Entertainment/Publishing
# 4                     Automotive

# %% [markdown]
# ### Reading Excel Files

# %%
df =pd.read_excel('Financial Sample.xlsx')
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera           NaN      1618.5
# 1  Government  Germany  Carretera           NaN      1321.0
# 2   Midmarket   France  Carretera           NaN      2178.0
# 3   Midmarket  Germany  Carretera           NaN       888.0
# 4   Midmarket   Mexico  Carretera           NaN      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %% [markdown]
# ### Reading Json file

# %%
df=pd.read_json('json file.json')
df.head()
# Out:
#             name language                id  \
# 0  Adeel Solangi   Sindhi  V59OF92YF627HFY0
# 1  Afzal Ghaffar   Sindhi  ENTOCR13RSCLZ6KU
# 2  Aamir Solangi   Sindhi  IAKPO3R4761JDRVG
# 3  Abla Dilmurat   Uyghur  5ZVOEPMJUI4MB4EN
# 4       Adil Eli   Uyghur  6VTI8X6LL0MMPJCC
#
#                                                  bio  version
# 0  Donec lobortis eleifend condimentum. Cras dict...     6.10
# 1  Aliquam sollicitudin ante ligula, eget malesua...     1.88
# 2  Vestibulum pharetra libero et velit gravida eu...     7.27
# 3  Donec lobortis eleifend condimentum. Morbi ac ...     2.53
# 4  Vivamus id faucibus velit, id posuere leo. Mor...     6.49

# %% [markdown]
# ### Reading an image using Pillow

# %%
from PIL import Image


image = Image.open('flower.jpg')

# Displaying the image using Pillow's show method
image.show()

# %% [markdown]
# ### Reading an image using OpenCV

# %%
import cv2

image = cv2.imread('flower.jpg')

# Displaying the image using OpenCV's imshow method
cv2.imshow('Image', image)
cv2.waitKey(0)  # Wait for a key press to close the window
cv2.destroyAllWindows()

# %% [markdown]
# ### Reading an image using imageio

# %%
import imageio
import matplotlib.pyplot as plt

image = imageio.imread('flower.jpg')

# Displaying the image using matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axes
plt.show()
# Out:
# C:\Users\Prajwal\AppData\Local\Temp\ipykernel_13936\3367114304.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread('flower.jpg')
